# %% [markdown]
# # Python Refresher

# %% [markdown]
# ### 1. Built-in Data Types & Data Structures

# %% [markdown]
# #### 1.1 Numeric Types

# %%
a = 10
type(a)
# Out:
# int

# %%
a = 24.
type(a)
# Out:
# float

# %%
a = 5 + 3j
type(a)
# Out:
# complex

# %% [markdown]
# #### 1.2 Sequence Types

# %%
a = 'This is a string'
type(a)
# Out:
# str

# %%
b = "This is a string"
type(b)
# Out:
# str

# %%
c = '''This is a very
long string'''

type(c)
# Out:
# str

# %%
li = [1, 2, 3, 4, 4.5, 'abc', 2 + 5j]
type(li)
# Out:
# list

# %%
t = (1, 2, 3)
type(t)
# Out:
# tuple

# %%
t1 = 5, 6, 7
type(t1)
# Out:
# tuple

# %%
z = (6.5)
type(z)
# Out:
# float

# %%
z = 6.5,
type(z)
# Out:
# tuple

# %%
r = range(5)
# type(r)
print(list(r))
# Out:
# [0, 1, 2, 3, 4]

# %%
r
# Out:
# range(0, 5)

# %% [markdown]
# #### 1.3 Set Types

# %%
s1 = {2, 3, 4}
type(s1)
# Out:
# set

# %%
s2 = {2, 3, 4, 5, 4, 5, 5, 5, 4}
s2
# Out:
# {2, 3, 4, 5}

# %%
s3 = frozenset({1, 2})
type(s3)
# Out:
# frozenset

# %% [markdown]
# #### 1.4 Mapping Types

# %%
d = {
    'name': 'Jack',
    'age': 25,
    'occupation': 'Engineer'
}

type(d)
# Out:
# dict

# %% [markdown]
# #### 1.5 Boolean Types

# %%
a = True
type(a)
# Out:
# bool

# %%
a = False
type(a)
# Out:
# bool

# %% [markdown]
# #### 1.6 None Type

# %%
a = None
type(a)
# Out:
# NoneType

# %% [markdown]
# ### 2. Control Structures

# %% [markdown]
# #### 2.1 if-else

# %%
a = -1

if a > 5:
    print('Greater than 5')
else:
    print('Not greater than 5')
# Out:
# Not greater than 5

# %%
a = 8

if a % 2 == 0:
    print('Even')
else:
    print('Odd')
# Out:
# Even

# %% [markdown]
# #### 2.2 if-elif-else

# %%
marks = 26

if marks > 90:
    print('Excellent')
elif marks > 70:
    print('Very Good')
elif marks > 50:
    print('Good')
else:
    print('Bad')
# Out:
# Bad

# %% [markdown]
# ### 3. Loops

# %% [markdown]
# #### 3.1 For loop

# %%
li = [1, 2, 3, 6, 9]

print(li[0])
print(li[1])
print(li[2])
print(li[3])
print(li[4])
# Out:
# 1
# 2
# 3
# 6
# 9

# %%
for element in li:
    print(element)
# Out:
# 1
# 2
# 3
# 6
# 9

# %%
for element in range(20, 31):
    if element % 2 == 0:
        print(element)
# Out:
# 20
# 22
# 24
# 26
# 28
# 30

# %%
for element in range(20, 31, 2):
    print(element)
# Out:
# 20
# 22
# 24
# 26
# 28
# 30

# %% [markdown]
# #### 3.2 While loop

# %%
a = 1

while a <= 5:
    print(a)
    a += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ### 4. Functions

# %% [markdown]
# #### 4.1 Definition/Call

# %%
def random_func():
    print('This is a random function')

# %%
random_func()
# Out:
# This is a random function

# %%
def add_numbers():
    a = 2 + 3
    print(a)

# %%
add_numbers()
# Out:
# 5

# %% [markdown]
# #### 4.2 Input to functions

# %%
def add_two_numbers(a, b):
    print(f'Sum of {a} and {b} is {a + b}')

# %%
add_two_numbers(3, 4)
# Out:
# Sum of 3 and 4 is 7

# %%
def greeting(name):
    print(f'Hi {name}, good morning!')

# %%
greeting('Jack')
# Out:
# Hi Jack, good morning!

# %% [markdown]
# #### 4.3 Output from functions

# %%
def add_two_numbers(a, b):
    print(f'Sum of {a} and {b} is {a + b}')

# %%
c = add_two_numbers(5, 8)
# Out:
# Sum of 5 and 8 is 13

# %%
print(c)
# Out:
# None

# %%
def add_two_numbers(a, b):
    res = a + b
    print(f'Sum of {a} and {b} is {res}')
    return res

# %%
c = add_two_numbers(4, 5)
# Out:
# Sum of 4 and 5 is 9

# %%
print(c)
# Out:
# 9

# %%
def greeting(name):
    return f'Hi {name}, good morning!'

# %%
greeting('Jack')
# Out:
# 'Hi Jack, good morning!'

# %%
c =  greeting('John')

# %%
print(c)
# Out:
# Hi John, good morning!

# %% [markdown]
# ### 5. Built-in Functions

# %%
li = [5, 6, 4, 3, 2, 8]

# %% [markdown]
# #### 5.1 min

# %%
min(li)
# Out:
# 2

# %%
min((3, 4, -4, -2, 6, 0))
# Out:
# -4

# %%
min(['aaron', 'ben', 'jack', 'tom'])
# Out:
# 'aaron'

# %% [markdown]
# #### 5.2 max

# %%
max(li)
# Out:
# 8

# %%
max((3, 4, -4, -2, 6, 0))
# Out:
# 6

# %%
max(['aaron', 'ben', 'jack', 'tom'])
# Out:
# 'tom'

# %% [markdown]
# #### 5.3 sum

# %%
sum(li)
# Out:
# 28

# %%
sum((3, 4, -4, -2, 6, 0))
# Out:
# 7

# %% [markdown]
# #### 5.4 len

# %%
len(li)
# Out:
# 6

# %%
len(['aaron', 'ben', 'jack', 'tom'])
# Out:
# 4

# %%
li
# Out:
# [5, 6, 4, 3, 2, 8]

# %%
sum(li) / len(li)
# Out:
# 4.666666666666667

# %% [markdown]
# #### 5.5 sorted

# %%
li
# Out:
# [5, 6, 4, 3, 2, 8]

# %%
sorted_li = sorted(li)
sorted_li
# Out:
# [2, 3, 4, 5, 6, 8]

# %%
type(sorted_li)
# Out:
# list

# %%
li
# Out:
# [5, 6, 4, 3, 2, 8]

# %%
sorted((6, 4, -1, -3, 0, 45, 21))
# Out:
# [-3, -1, 0, 4, 6, 21, 45]

# %% [markdown]
# #### 5.6 enumerate

# %%
names = ['Bruce', 'Peter', 'Barry', 'Steve', 'Diana']

# %%
list(range(len(names)))
# Out:
# [0, 1, 2, 3, 4]

# %%
for i in range(len(names)):
    print(i, names[i])
# Out:
# 0 Bruce
# 1 Peter
# 2 Barry
# 3 Steve
# 4 Diana

# %%
for i, name in enumerate(names):
    print(i, name)
# Out:
# 0 Bruce
# 1 Peter
# 2 Barry
# 3 Steve
# 4 Diana

# %%
for i, name in enumerate(names, start=1):
    print(i, name)
# Out:
# 1 Bruce
# 2 Peter
# 3 Barry
# 4 Steve
# 5 Diana

# %% [markdown]
# #### 5.7 zip

# %%
names
# Out:
# ['Bruce', 'Peter', 'Barry', 'Steve', 'Diana']

# %%
colors = ['red', 'blue', 'orange', 'pink', 'black']
ages = [23, 34, 27, 31, 35]

# %%
for name, age, color in zip(names, ages, colors):
    print(f'{name} is {age} years old and they like the color {color}.')
# Out:
# Bruce is 23 years old and they like the color red.
# Peter is 34 years old and they like the color blue.
# Barry is 27 years old and they like the color orange.
# Steve is 31 years old and they like the color pink.
# Diana is 35 years old and they like the color black.

# %% [markdown]
# ### 6. List Comprehensions

# %%
result = []

for i in range(1, 11):
    if i % 2 == 0:
        result.append(i)

result
# Out:
# [2, 4, 6, 8, 10]

# %%
list(range(2, 11, 2))
# Out:
# [2, 4, 6, 8, 10]

# %%
seq = range(1, 11)

[a for a in seq if a % 2 == 0]
# Out:
# [2, 4, 6, 8, 10]

# %%
ages
# Out:
# [23, 34, 27, 31, 35]

# %%
for age in ages:
    if age > 30:
        print('Greater than 30')
    else:
        print('Less than 30')
# Out:
# Less than 30
# Greater than 30
# Less than 30
# Greater than 30
# Greater than 30

# %%
['Greater than 30' if age > 30 else 'Less than 30' for age in ages]
# Out:
# ['Less than 30',
#  'Greater than 30',
#  'Less than 30',
#  'Greater than 30',
#  'Greater than 30']

# %% [markdown]
# ### 7. Classes

# %%
class MyRectangle:
    def __init__(self, length, breadth):
        self.length = length
        self.breadth = breadth
        self.random_attribute = 0
        self.another_random_attribute = 'abc'

    def get_perimeter(self):
        return 2 * (self.length + self.breadth)

    def get_area(self):
        return self.length * self.breadth

    def get_length(self):
        return self.length

    def get_breadth(self):
        return self.breadth

# %%
obj1 = MyRectangle(length=5, breadth=6)

# %%
obj2 = MyRectangle(length=10, breadth=12)

# %%
obj1

# %%
obj1.breadth
# Out:
# 6

# %%
obj1.random_attribute
# Out:
# 0

# %%
obj1.another_random_attribute
# Out:
# 'abc'

# %%
obj1.get_length()
# Out:
# 5

# %%
MyRectangle.get_length(obj1)
# Out:
# 5

# %%
MyRectangle.get_length(obj2)
# Out:
# 10

# %%
obj1.get_area()
# Out:
# 30

# %%
obj2.get_area()
# Out:
# 120
